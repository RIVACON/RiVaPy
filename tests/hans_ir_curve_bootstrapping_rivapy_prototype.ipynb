# %% [markdown]
# Put logo

# %% [markdown]
# ## Curve Bootstrapping

# %%
# %load_ext autoreload
# %autoreload 2

#imports
import datetime as dt
from dateutil.relativedelta import relativedelta
import pandas as pd
import matplotlib.pyplot as plt
from rivapy.marketdata.bootstrapping_2025 import bootstrap_curve, get_quote
from rivapy.instruments.deposit_specifications import DepositSpecification
from rivapy.instruments.fra_specifications import ForwardRateAgreementSpecification
from rivapy.instruments.ir_swap_specification import InterestRateSwapSpecification, IrFixedLegSpecification, IrFloatLegSpecification
from rivapy.instruments.notional_structure import ConstNotionalStructure
from rivapy.tools.enums import DayCounterType, InterpolationType, ExtrapolationType

import matplotlib.pyplot as plt
import math
from rivapy.tools.datetools import DayCounter
from rivapy.tools._validators import print_member_values
from rivapy.pricing.deposit_pricing import DepositPricer
from rivapy.pricing.interest_rate_swap_pricing import InterestRateSwapPricer
from rivapy.marketdata.curves import DiscountCurve
# Out:
# c:\Users\DrHansNguyen\anaconda3\envs\rivapy3.11\Lib\site-packages\pyvacon\__init__.py:12: UserWarning: Imported pyvacon is just beta version.
#   _warnings.warn('Imported pyvacon is just beta version.')
# c:\Users\DrHansNguyen\Documents\MyRivacon\RiVaPy\rivapy\__init__.py:9: UserWarning: Imported pyvacon is just beta version.
#   warnings.warn('Imported pyvacon is just beta version.')

# %%
#set up instruments
#set up deposit
#set up ir_swap

# %% [markdown]
# ### Setting up deposits / fixings
#
# The fixing of the underlying reference rate is published daily and represents a certain average rate earned over a period corresponding to the tenor. The rate is calculated from quotes obtained from a panel of selected banks. The start date (spot date) of the period can deviate from the fixing date. This difference is referred to as the spot lag.
#
# The fixing is usually used as the starting point for the bootstrapping of forward curves. It can be specified as a deposit in pyvacon.

# %%
##########################################
# setting up depoist
# calculation date
ref_date = dt.datetime(2019, 8, 31)

# start date of the accrual period with spot lag equal to 2 days
start_date = ref_date + dt.timedelta(days=2)

# end date of the accrual period is 1 day after startdate
end_date = start_date + dt.timedelta(days=1)

# specification of the deposit
# deposit = pyvacon.finance.specification.DepositSpecification(
#     'OVERNIGHT_DEPOSIT', 'dummy_issuer', 'NONE', 'EUR',
#     refdate, startdate, enddate, 100, 0.01, 'Act365Fixed')
ccy = "EUR"
dcc = "Act365Fixed"#"Act360"#"Act365Fixed"#"Act360"
rate = 0.01
notional = 100.0
deposit = DepositSpecification(
    obj_id="OVERNIGHT_DEPOSIT",
    issuer="dummy_issuer",
    currency=ccy,
    fixing_date=ref_date,
    start_date=start_date,
    maturity_date=end_date,
    notional=notional,
    rate=rate,
    day_count_convention=dcc,
)

# check dates, deposit start date cannot be the same as  maturity date
print(f"ref date: {ref_date}")
print(f"start date: {start_date} with spot lag 2 days")
print(f"end date: {end_date}")
print(f"adjusted start date: {deposit.start_date}")
print(f"adjusted end date: {deposit.maturity_date}")

print_member_values(deposit)



end_date_deposits = [
    start_date + dt.timedelta(days=1),
    start_date + dt.timedelta(days=7),
    start_date + dt.timedelta(days=30),
    start_date + dt.timedelta(days=60),
    start_date + dt.timedelta(days=90),
    start_date + dt.timedelta(days=180),
    start_date + dt.timedelta(days=270),
    start_date + dt.timedelta(days=360),
]

quotes_deposits = [0.025,0.028, 0.0283, 0.029, 0.0305, 0.0315, 0.0348, 0.05]
epsilon = 0#0.007
other_deposits = []

for i in range(len(quotes_deposits)):
    temp_deposit = DepositSpecification(
        obj_id="DEPOSIT_" + str(i + 1),
        issuer="dummy_issuer",
        currency=ccy,
        fixing_date=ref_date,
        start_date=start_date,
        maturity_date=end_date_deposits[i],
        notional=notional,
        rate=quotes_deposits[i] + epsilon,
        day_count_convention=dcc,
    )
    other_deposits.append(temp_deposit)
# Out:
# ref date: 2019-08-31 00:00:00
# start date: 2019-09-02 00:00:00 with spot lag 2 days
# end date: 2019-09-03 00:00:00
# adjusted start date: 2019-09-02 00:00:00
# adjusted end date: 2019-09-03 00:00:00
# Inspecting instance of DepositSpecification:
#
# business_day_convention: RollConvention.MODIFIED_FOLLOWING
# calendar: {datetime.date(2019, 1, 1): "New Year's Day", datetime.date(2019, 4, 19): 'Good Friday', datetime.date(2019, 4, 22): 'Easter Monday', datetime.date(2019, 5, 1): 'Labour Day', datetime.date(2019, 12, 25): 'Christmas Day', datetime.date(2019, 12, 26): 'Christmas Holiday'}
# coupon: 0.01
# currency: EUR
# day_count_convention: Act365Fixed
# fixing_date: 2019-08-31 00:00:00
# frequency: 1D
# issuer: dummy_issuer
# maturity_date: 2019-09-03 00:00:00
# notional: 100.0
# notional_exchange: True
# pays_in_arrears: True
# roll_convention: RollRule.EOM
# securitization_level: NONE
# settlement_days: 0
# start_date: 2019-09-02 00:00:00

# %%
print(f"ref date: {ref_date}")
print(f"start date: {start_date} with spot lag 2 days")
print(f"end date: {end_date}")
print(f"adjusted start date: {deposit.start_date}")
print(f"adjusted end date: {deposit.maturity_date}")

# %%
#additional set of test deposits taken from inputQuotes.csv
#RiVaPy\notebooks\marketdata\inputQuotes.csv
end_date_deposits_csv = [
    start_date + dt.timedelta(days=1),
    start_date + dt.timedelta(days=90),
    start_date + dt.timedelta(days=180),
    start_date + dt.timedelta(days=270),
]

#quotes_deposits_csv = [-0.00345, -0.00329, -0.00327672, -0.00323786] #why in teh data it is negative?
quotes_deposits_csv = [0.00323786, 0.00327672, 0.00329, 0.00345] #sorted to be increasing with maturity...
other_deposits_csv = []

for i in range(len(quotes_deposits_csv)):
    temp_deposit = DepositSpecification(
        obj_id="DEPOSIT_" + str(i + 1),
        issuer="dummy_issuer",
        currency=ccy,
        fixing_date=ref_date,
        start_date=start_date,
        maturity_date=end_date_deposits[i],
        notional=notional,
        rate=0.01,#the rate here should not matter as impliedSImplyCompoundedrate does not care
        day_count_convention=dcc,
    )
    other_deposits_csv.append(temp_deposit)

# %%
# #TOGGLE THIS FOR TESTING
# quotes_deposits = quotes_deposits_csv 
# other_deposits = other_deposits_csv
# end_date_deposits = end_date_deposits_csv


instruments = other_deposits
quotes = quotes_deposits

# instruments = other_deposits_csv
# quotes = quotes_deposits_csv
# estr = bootstrap_curve(ref_date, 'ESTR_DC', DayCounterType.ACT360,  
#                        instruments, quotes, interpolation_type=InterpolationType.LINEAR_LOG)

estr = bootstrap_curve(ref_date, 'ESTR_DC', DayCounterType.Act365Fixed,  
                      instruments, quotes, interpolation_type=InterpolationType.LINEAR_LOG)

# %%
# # sample 3M EURIBOR curve with ois discounting (the same instruments are used for simplification)
# quotes = [0.003, 0.0075]

# euribor_3m = bootstrap_curve(ref_date, 'EUR3M_DC', 'Act365Fixed', instruments, quotes, estr)

# %%
# # sample 6M EURIBOR curve with ois bootstrapping and the 3M EURIBOR curve as the basis index
# quotes = [0.003, 0.006]
# # the basis swap is used instead of the ir swap
# instruments[1] = basis_swap #TODO basis swaps are not yet implemented
# euribor_6m = bootstr.bootstrap_curve(refdate, 'EUR6M_DC', 'Act365Fixed', instruments, quotes, estr, euribor_3m)

# %%
# estr.plot()
# euribor_3m.plot()
# #euribor_6m.plot()

# %%
# plt.figure(1)
# estr.plot(discount_factors=True)
# plt.xlabel("year")
# plt.ylabel("DF")
# plt.legend()

# plt.figure(2)
# estr.plot(discount_factors=False)
# plt.xlabel("year")
# plt.ylabel("zero rate")
# plt.legend()

plt.figure(3)
dates_final = estr.get_dates()
df_final = estr.get_df()

# calculated df from dates
dates_new = [dates_final[0]]
days = 10  # create a smoother curve by adding dates in between
for i in range(1, len(dates_final)):
    while dates_new[-1] + dt.timedelta(days=days) < dates_final[i]:
        dates_new.append(dates_new[-1] + dt.timedelta(days=days))
    dates_new.append(dates_final[i])

#print(dates_new)
values = [estr.rivapy_value(estr.refdate, d) for d in dates_new]
#print(values)

plt.plot(dates_final, df_final, marker="^", label="bootstrapped")

plt.plot(dates_new, values, label="interpolated")

plt.xlabel("year")
plt.ylabel("DF")
plt.legend()

# continuous compounding
plt.figure(4)
dcc = DayCounter(estr.daycounter)
zero_final = []
for i in range(1, len(df_final)):
    delta_t = dcc.yf(estr.refdate, dates_final[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_final.append(-math.log(df_final[i]) / delta_t)
zero_final.insert(0, zero_final[0])  # adding first entry to account for division by zero for dt

zero_interp = []
for i in range(1, len(values)):
    delta_t = dcc.yf(estr.refdate, dates_new[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_interp.append(-math.log(values[i]) / delta_t)
zero_interp.insert(0, zero_interp[0])

plt.plot(dates_final, zero_final, marker="^", label="bootstrapped")
#plt.scatter(end_date_deposits, quotes_deposits)
plt.plot(dates_new, zero_interp, label="interpolated")

plt.xlabel("year")
plt.ylabel("zero rates")
plt.legend()
plt.show()

# %%
len(dates_new)
for i in dates_new:
    print(i)

# %%
dc_dates= estr.get_dates()
print(dc_dates)
print(len(dc_dates))
for i in dc_dates:
    print(i)

# %%
end_date_deposits
for i in end_date_deposits:
    print(i)

# %%
print(len(end_date_deposits))
print(len(dates_final))

# %%
for i in range(len(quotes_deposits)):
    #print(f"i:{i} date:{dates_final[i+1]}  zero:{zero_final[i+1]} quote:{quotes_deposits[i]}")
    print(f"i:{i} date:{dates_final[i+1]}  zero:{zero_final[i+1]} date:{end_date_deposits[i]} quote:{quotes_deposits[i]}")

#tolerance 1e-6
# i:0 date:2019-09-03 00:00:00  zero:0.05169734842475251 quote:0.051
# i:1 date:2019-09-09 00:00:00  zero:0.051842710069517586 quote:0.0512
# i:2 date:2019-10-02 00:00:00  zero:0.05207793548329917 quote:0.0515
# i:3 date:2019-11-01 00:00:00  zero:0.05227466599231794 quote:0.0518
# i:4 date:2019-12-02 00:00:00  zero:0.05236399478862491 quote:0.052
# i:5 date:2020-02-28 00:00:00  zero:0.05253685303257888 quote:0.0525
# i:6 date:2020-05-29 00:00:00  zero:0.05249461785244582 quote:0.0528
# i:7 date:2020-08-27 00:00:00  zero:0.05235681622842124 quote:0.053

# %%
print_member_values(other_deposits[5])

# %%
new_df = []
for i in range(len(end_date_deposits)) :
    val = estr.rivapy_value(estr.refdate, end_date_deposits[i])
    new_df.append(val)
    print(val)
    delta_t = dcc.yf(estr.refdate, end_date_deposits[i])
    discount_factor = math.exp(-1*val*delta_t)

# %%
simply_rate = []
for i in range(len(other_deposits)):
    val =DepositPricer.implied_simply_compounded_rate(ref_date, other_deposits[i], estr)
    simply_rate.append(val)

# %%
for i in range(len(quotes_deposits)):
    #per_diff = (zero_final[i+1] - quotes_deposits[i])/quotes_deposits[i] * 100
    #print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")

    per_diff = (simply_rate[i] - quotes_deposits[i])/quotes_deposits[i] * 100
    print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")


#tolerance 1e-6
# i:0 date:2019-09-03 00:00:00  percent diff: 1.3673498524559047
# i:1 date:2019-09-09 00:00:00  percent diff: 1.255293104526531
# i:2 date:2019-10-02 00:00:00  percent diff: 1.1222048219401421
# i:3 date:2019-11-01 00:00:00  percent diff: 0.916343614513402
# i:4 date:2019-12-02 00:00:00  percent diff: 0.6999899781248362
# i:5 date:2020-02-28 00:00:00  percent diff: 0.07019625253120086
# i:6 date:2020-05-29 00:00:00  percent diff: -0.5783752794586687
# i:7 date:2020-08-27 00:00:00  percent diff: -1.213554285997656

# %%
dc_df= estr.get_df()
for i in range(len(dc_df)):
    print(f"i:{i} date:{dates_final[i]}  DF: {dc_df[i]}")

# %%
continous_compound_DF = []

for i in range(len(end_date_deposits)):
    delta_t = dcc.yf(estr.refdate, end_date_deposits[i])
    discount_factor = math.exp(-1*quotes_deposits[i]*delta_t)
    continous_compound_DF.append(discount_factor)
    
for i in range(len(end_date_deposits)):
    print(f"i:{i} date:{end_date_deposits[i]}  DF: {continous_compound_DF[i]}")

# %%
len(end_date_deposits)
for i in end_date_deposits:
    print(i)

# %%
len(continous_compound_DF)

# %%
len(quotes_deposits)

# %%
for i in range(len(continous_compound_DF)):
    per_diff = (dc_df[i+1] - continous_compound_DF[i])/continous_compound_DF[i] * 100
    print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")

# %%
annual_compound_DF = []
for i in range(len(end_date_deposits)):
    delta_t = dcc.yf(estr.refdate, end_date_deposits[i])
    discount_factor = 1 / ((1 + quotes_deposits[i]) ** delta_t)
    annual_compound_DF.append(discount_factor)
    
for i in range(len(end_date_deposits)):
    print(f"i:{i} date:{end_date_deposits[i]}  DF: {annual_compound_DF[i]}")

# %%
for i in range(len(annual_compound_DF)):
    per_diff = (dc_df[i+1] - annual_compound_DF[i])/annual_compound_DF[i] * 100
    print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")

# %% [markdown]
# ## SWAPS

# %% [markdown]
# ### Setting up an interest rate swap
# A plain vanilla interest rate swap is a financial contract in which a stream of fixed payments is exchanged for floating payments linked to a reference index. The par rate (r) of a swap is the fixed rate under which the value of the two streams (legs) is equal:
# $$ r \cdot \sum_{i=1}^n dcf_{i} \cdot P(0,t_{i} ) = \sum_{k=1}^m F_{k} \cdot dcf_{k} \cdot P(0,t_{k}) $$
#
# where $t_{i}$, $i=1,..,n$ and $t_{k}$, $i=1,..,m$ are the payment structures of the fixed and floating legs, and $P(0,t_{i/k})$ are the corresponding discount factors, $dcf_{i/k}$ is the day count fraction for the period $[t_{(i/k-1)},t_{i/k}]$, and $F_{k}$ is the expected value of  underlying reference rate for the period $[t_{(k-1)},t_{k}]$.
#
# The standard payment frequency of the fixed leg depends on the currency of the swap as well as the tenor of the underlying. In the EUR market swaps are usually quoted with annual fixed payments.
#
# The payment frequency of the floating leg usually coincides with the tenor of the underlying reference index. In some currencies, however, the floating rate can be compounded and payed out at less frequent intervals (e.g. CAD).
#
# In the context of pyvacon an IRS can be defined using an InterestRateSwapSpecification.

# %%
#ref_date = is the same as was in deposits

#1Y maturity swap quarterly payments
# start dates of the accrual periods corresponding to the tenor of the underlying index (3 months). The spot lag is set to 0.
start_dates = [ref_date + relativedelta(months=3*i) for i in range(4)]

# reset dates are equal to start dates if spot lag is 0.
reset_dates = start_dates

# the end dates of the accral periods
end_dates = [x + relativedelta(months=3) for x in start_dates]

# the actual payment dates of the cashflows may differ from the end of the accrual period (e.g. OIS). 
# in the standard case these two sets of dates coincide
pay_dates = end_dates
#notionals = [1.0 for i in range(len(start_dates))] #i.e constant ...

print(end_dates)
ns = ConstNotionalStructure(100.0)
spread = 0.00

# # definition of the floating leg
float_leg =IrFloatLegSpecification(obj_id = 'dummy_float_leg', notional = ns, reset_dates=reset_dates, start_dates=start_dates, end_dates=end_dates,
                                   rate_start_dates=start_dates, rate_end_dates=end_dates, pay_dates=pay_dates, currency = "EUR", 
                                   udl_id="test_udl_id", fixing_id="test_fixing_id", day_count_convention="Act365Fixed", spread=spread)

# # definition of the fixed leg
fixed_leg = IrFixedLegSpecification(fixed_rate = 0.01, obj_id = 'dummy_fixed_leg', notional = 100.0, start_dates=start_dates, 
                                    end_dates=end_dates, pay_dates=pay_dates, currency='EUR', day_count_convention='Act365Fixed')

# # definition of the IR swap
ir_swap = InterestRateSwapSpecification(obj_id="3M_SWAP", notional=ns, issue_date=ref_date, maturity_date=pay_dates[-1],
                                        pay_leg=fixed_leg, receive_leg=float_leg,currency='EUR', day_count_convention="Act365Fixed",
                                        issuer="dummy_issuer", securitization_level="COLLATERALIZED")
# Out:
# [datetime.datetime(2019, 11, 30, 0, 0), datetime.datetime(2020, 2, 29, 0, 0), datetime.datetime(2020, 5, 29, 0, 0), datetime.datetime(2020, 8, 31, 0, 0)]

# %%
#2Y maturity swap quarterly payments
# start dates of the accrual periods corresponding to the tenor of the underlying index (3 months). The spot lag is set to 0.
start_dates2 = [ref_date + relativedelta(months=3*i) for i in range(4*2)]

# reset dates are equal to start dates if spot lag is 0.
reset_dates2 = start_dates2

# the end dates of the accral periods
end_dates2 = [x + relativedelta(months=3) for x in start_dates2]

# the actual payment dates of the cashflows may differ from the end of the accrual period (e.g. OIS). 
# in the standard case these two sets of dates coincide
pay_dates2 = end_dates2
#notionals = [1.0 for i in range(len(start_dates))] #i.e constant ...

ns = ConstNotionalStructure(100.0)
spread = 0.00

# # definition of the floating leg
float_leg2 =IrFloatLegSpecification(obj_id = 'dummy_float_leg2', notional = ns, reset_dates=reset_dates2, start_dates=start_dates2, end_dates=end_dates2,
                                   rate_start_dates=start_dates2, rate_end_dates=end_dates2, pay_dates=pay_dates2, currency = "EUR", 
                                   udl_id="test_udl_id", fixing_id="test_fixing_id", day_count_convention="Act365Fixed", spread=spread)

# # definition of the fixed leg
fixed_leg2 = IrFixedLegSpecification(fixed_rate = 0.01, obj_id = 'dummy_fixed_leg2', notional = 100.0, start_dates=start_dates2, 
                                    end_dates=end_dates2, pay_dates=pay_dates2, currency='EUR', day_count_convention='Act365Fixed')

# # definition of the IR swap
ir_swap2 = InterestRateSwapSpecification(obj_id="3M_SWAP2", notional=ns, issue_date=ref_date, maturity_date=pay_dates2[-1],
                                        pay_leg=fixed_leg2, receive_leg=float_leg2,currency='EUR', day_count_convention="Act365Fixed",
                                        issuer="dummy_issuer", securitization_level="COLLATERALIZED")

# %%
#3Y maturity swap quarterly payments
# start dates of the accrual periods corresponding to the tenor of the underlying index (3 months). The spot lag is set to 0.
start_dates3 = [ref_date + relativedelta(months=3*i) for i in range(4*3)]

# reset dates are equal to start dates if spot lag is 0.
reset_dates3 = start_dates3

# the end dates of the accral periods
end_dates3 = [x + relativedelta(months=3) for x in start_dates3]

# the actual payment dates of the cashflows may differ from the end of the accrual period (e.g. OIS). 
# in the standard case these two sets of dates coincide
pay_dates3 = end_dates3
#notionals = [1.0 for i in range(len(start_dates))] #i.e constant ...

ns = ConstNotionalStructure(100.0)
spread = 0.00

# # definition of the floating leg
float_leg3 =IrFloatLegSpecification(obj_id = 'dummy_float_leg3', notional = ns, reset_dates=reset_dates3, start_dates=start_dates3, end_dates=end_dates3,
                                   rate_start_dates=start_dates3, rate_end_dates=end_dates3, pay_dates=pay_dates3, currency = "EUR", 
                                   udl_id="test_udl_id", fixing_id="test_fixing_id", day_count_convention="Act365Fixed", spread=spread)

# # definition of the fixed leg
fixed_leg3 = IrFixedLegSpecification(fixed_rate = 0.01, obj_id = 'dummy_fixed_leg3', notional = 100.0, start_dates=start_dates3, 
                                    end_dates=end_dates3, pay_dates=pay_dates3, currency='EUR', day_count_convention='Act365Fixed')

# # definition of the IR swap
ir_swap3 = InterestRateSwapSpecification(obj_id="3M_SWAP3", notional=ns, issue_date=ref_date, maturity_date=pay_dates3[-1],
                                        pay_leg=fixed_leg3, receive_leg=float_leg3,currency='EUR', day_count_convention="Act365Fixed",
                                        issuer="dummy_issuer", securitization_level="COLLATERALIZED")

# %%
# other_swaps = [ir_swap]
# quotes_swaps = [0.01]
# other_swaps = [ir_swap2]
# quotes_swaps = [0.02]
# other_swaps = [ir_swap, ir_swap2]
# quotes_swaps = [0.01, 0.02]
other_swaps = [ir_swap, ir_swap2, ir_swap3]
quotes_swaps = [0.05, 0.06, 0.07]


estr = bootstrap_curve(ref_date, 'ESTR_DC', DayCounterType.Act365Fixed,  
                       other_swaps, quotes_swaps)

# %%
# plt.figure(1)
# estr.plot(discount_factors=True)
# plt.xlabel("year")
# plt.ylabel("DF")
# plt.legend()

# plt.figure(2)
# estr.plot(discount_factors=False)
# plt.xlabel("year")
# plt.ylabel("zero rate")
# plt.legend()

# %%
plt.figure(3)
dates_final = estr.get_dates()
df_final = estr.get_df()

# calculated df from dates
dates_new = [dates_final[0]]
days = 10  # create a smoother curve by adding dates in between
for i in range(1, len(dates_final)):
    while dates_new[-1] + dt.timedelta(days=days) < dates_final[i]:
        dates_new.append(dates_new[-1] + dt.timedelta(days=days))
    dates_new.append(dates_final[i])

print(dates_new)
values = [estr.rivapy_value(estr.refdate, d) for d in dates_new]
print(values)

plt.plot(dates_final, df_final, marker="^", label="bootstrapped")
plt.plot(dates_new, values, label="interpolated")

plt.xlabel("year")
plt.ylabel("DF")
plt.legend()

# continuous compounding
plt.figure(4)
dcc = DayCounter(estr.daycounter)
zero_final = []
for i in range(1, len(df_final)):
    delta_t = dcc.yf(estr.refdate, dates_final[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_final.append(-math.log(df_final[i]) / delta_t)
zero_final.insert(0, zero_final[0])  # adding first entry to account for division by zero for dt

zero_interp = []
for i in range(1, len(values)):
    delta_t = dcc.yf(estr.refdate, dates_new[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_interp.append(-math.log(values[i]) / delta_t)
zero_interp.insert(0, zero_interp[0])

plt.plot(dates_final, zero_final, marker="^", label="bootstrapped")
# plt.scatter(end_date_deposits, quotes_deposits)
plt.plot(dates_new, zero_interp, label="interpolated")

plt.xlabel("year")
plt.ylabel("zero rates")
plt.legend()
plt.show()

# %%
swap_fair_rate = []
pricing_params = {"fixing_grace_period": 0.0, "set_rate": True, "desired_rate": 1.0}
for i in range(len(other_swaps)):
    instrument_spec = other_swaps[i]
    float_leg = instrument_spec.get_float_leg()
    fixed_leg = instrument_spec.get_fixed_leg()
    yc_discount = estr  # TODO decide how to pass which curves
    yc_forward = estr
    val = InterestRateSwapPricer.compute_swap_rate(ref_date, yc_discount, yc_forward, 
                                                    float_leg, fixed_leg, None, pricing_params)
    print(val)
    swap_fair_rate.append(val)

# %%
for i in range(len(quotes_swaps)):

    per_diff = (swap_fair_rate[i] - quotes_swaps[i])/quotes_swaps[i] * 100
    print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")

# %% [markdown]
# ## DEPOSITS AND SWAPS

# %%
other_swaps = [ir_swap, ir_swap2, ir_swap3]
quotes_swaps = [0.05, 0.06, 0.07]

#we omit the 1 year deposit so as to not overlap with the swap
instruments_both = other_deposits[:-1] + other_swaps
quotes_both = quotes_deposits[:-1] + quotes_swaps

# instruments_both = other_deposits[:-1] + [other_swaps[0]]
# quotes_both = quotes_deposits[:-1] + [quotes_swaps[0]]


# instruments_both = [deposit, ir_swap]
# quotes_both = [0.025, 0.05]

estr_both = bootstrap_curve(ref_date, 'ESTR_DC', DayCounterType.Act365Fixed,  
                       instruments_both, quotes_both, 
                       interpolation_type =InterpolationType.LINEAR_LOG, 
                       extrapolation_type= ExtrapolationType.LINEAR_LOG)
# Out:
# IRS swap present but no fixing curve provided, will use bootstrapped curve in place
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 1.0]
# ----------------
# Error function trial curve
# (1.0, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 16576.799242686637
# ----------------
# Error function trial curve
# (1.0, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -151.5467051104607
# brentq evaluation at bounds
# f(1e-05) = 16576.774242686635
# f(5.0) = -151.5717051104607
# f(a)*f(b) = -2512569.937195179
# ----------------
# Error function trial curve
# (1.0, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 16576.799242686637
# ----------------
# Error function trial curve
# (1.0, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -151.5467051104607
# ----------------
# Error function trial curve
# (1.0, 4.954696237619652)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -150.89810076244623
# ----------------
# Error function trial curve
# (1.0, 2.477353118809826)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -95.2486918065504
# ----------------
# Error function trial curve
# (1.0, 1.238681559404913)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -25.13510586549917
# ----------------
# Error function trial curve
# (1.0, 0.7967163696566267)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 28.723754327728358
# ----------------
# Error function trial curve
# (1.0, 1.0322180189022385)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is -3.8377202237527612
# ----------------
# Error function trial curve
# (1.0, 0.9992138111858866)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.09570313725791091
# ----------------
# Error function trial curve
# (1.0, 0.9998070605806475)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.023477315885798156
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.024999410316817183
# ----------------
# Error function trial curve
# (1.0, 0.9997940535379856)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.025060260338479745
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.999794553537986]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 5213519.375937734
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -41.71571410526739
# brentq evaluation at bounds
# f(1e-05) = 5213519.347937734
# f(5.0) = -41.74371410526739
# f(a)*f(b) = -217631661.14259282
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 5213519.375937734
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -41.71571410526739
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 4.999959966297618)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -41.71563061717071
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 2.499984983148809)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -31.28844580064092
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 1.2499974915744045)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -10.434201294050231
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.6250037457872023)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 31.273787220262605
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 1.093221521098047)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -4.452874662835236
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9905041712477607)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.4926760546176437
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 1.0001553295506713)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is -0.015238914425380057
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.999333724295068)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.027617965170859047
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.0280000027975859
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993269063573301)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.02797389979922674
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9993264063573297]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 1216487.8543854712
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -9.733666624562392
# brentq evaluation at bounds
# f(1e-05) = 1216487.8260854713
# f(5.0) = -9.761966624562392
# f(a)*f(b) = -11875313.55743283
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 1216487.8543854712
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -9.733666624562392
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 4.9999598768333104)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -9.733647100472469
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 2.499984938416655)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -7.300637266415167
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 1.2499974692083275)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -2.4346467944776866
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.6250037346041638)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 7.297217366323774
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 1.0918236301804312)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is -1.0247570447701075
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9886319328480069)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.13821627948396564
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9983849058593961)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.01801294850631241
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975502423374396)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.028208031590731153
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.028300000693588845
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975432192499771)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.02829388819317865
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9975427192499767]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 608243.9271927356
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -4.866833312281196
# brentq evaluation at bounds
# f(1e-05) = 608243.8981927356
# f(5.0) = -4.895833312281196
# f(a)*f(b) = -2977860.7387637673
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 608243.9271927356
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -4.866833312281196
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 4.999959754761796)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -4.866823520535757
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 2.4999848773808977)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -3.6503185738068664
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 1.2499974386904489)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -1.2173232784383587
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.6250037193452245)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 3.648608920759052
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 1.089916247788076)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is -0.502629203447407
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9860886136490473)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.08497651333676873
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9959794448324396)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.023720518851326294
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951269820291487)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.028952048435687366
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.02900000037618796
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951196751463717)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.02899692922128546
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9951191751463713]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 588552.0272602412
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -3.2509215359233443
# brentq evaluation at bounds
# f(1e-05) = 588551.9967602412
# f(5.0) = -3.2814215359233443
# f(a)*f(b) = -1931287.197179742
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 588552.0272602412
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -3.2509215359233443
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 4.999972123136987)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -3.250917156983834
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 2.4999910615684935)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -2.4553168432018926
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 1.2500005307842468)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -0.8269336097605414
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.6250052653921234)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 2.505915452526845
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 1.0892095869181526)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is -0.3400882050496214
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9827524588472586)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.07153620569847192
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9933655237955842)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.026472858559755643
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924170741935198)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.03046013015981009
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.03050000038908993
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.992408099586878)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.03049789631251017
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9924075995868776]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 179414.12440534183
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -1.6239481076386928
# brentq evaluation at bounds
# f(1e-05) = 179414.09290534182
# f(5.0) = -1.6554481076386929
# f(a)*f(b) = -297010.72058386076
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 179414.12440534183
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -1.6239481076386928
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 4.999953865677569)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -1.623944319559281
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 2.4999819328387844)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -1.2151544111481818
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 1.2499959664193923)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -0.40385194939194996
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.6250029832096962)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 1.2062850556066378
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 1.0810091579975398)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is -0.15127289882356262
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9751892665573694)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.0511859322612434
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9854785841614542)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.029602568339998598
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845740320697117)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03148201424451453
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03150000015681727
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845658836684468)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03149896030796009
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9845653836684464]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 135165.31715394126
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -1.0815185138402659
# brentq evaluation at bounds
# f(1e-05) = 135165.28235394126
# f(5.0) = -1.1163185138402658
# f(a)*f(b) = -150887.50712015163
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 1e-05)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 135165.31715394126
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 5.0)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -1.0815185138402659
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 4.999958705851004)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -1.081516281184799
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 2.4999843529255017)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -0.8111817918667965
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 1.2499971764627509)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -0.2705160572519913
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.6250035882313755)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.8108024360744852
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 1.0735268956488588)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is -0.09276212104360841
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9647646966922979)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.049180643110006556
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9757837181716961)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.033359506860422966
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747804511120155)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.03478519910251325
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.03480000015798561
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747705463521553)
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.034799288887082835
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9747700463521549]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 1e-05)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 305358.22530630475
# delta_t: 0.25205479452054796
# discount_factor: 9.999999999999997e-06
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 76.96700473473982
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 0.0002520547945205479
# Calculated quote for Instrument.IRS is 1.0840790731795982
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 5.0)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: -3.1925790970864805
# delta_t: 0.25205479452054796
# discount_factor: 4.999999999999999
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# -402.35243415336464
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 126.02739726027396
# Calculated quote for Instrument.IRS is -2.0056149564728294
# brentq evaluation at bounds
# f(1e-05) = 1.0340790731795981
# f(5.0) = -2.055614956472829
# f(a)*f(b) = -2.125668409003543
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 1e-05)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 305358.22530630475
# delta_t: 0.25205479452054796
# discount_factor: 9.999999999999997e-06
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 76.96700473473982
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 0.0002520547945205479
# Calculated quote for Instrument.IRS is 1.0840790731795982
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 5.0)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: -3.1925790970864805
# delta_t: 0.25205479452054796
# discount_factor: 4.999999999999999
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# -402.35243415336464
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 126.02739726027396
# Calculated quote for Instrument.IRS is -2.0056149564728294
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 1.673439464369615)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: -1.6430740197091969
# delta_t: 0.25205479452054796
# discount_factor: 1.673439464369615
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# -69.30460588670812
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 42.179844033425915
# Calculated quote for Instrument.IRS is -0.5781453932303643
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 1.041059764647112)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: -0.2494543905939004
# delta_t: 0.25205479452054796
# discount_factor: 1.041059764647112
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# -6.545785611751363
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 26.240410506173784
# Calculated quote for Instrument.IRS is -0.04038178688740691
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9433187502962619)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.13048112620896024
# delta_t: 0.25205479452054796
# discount_factor: 0.9433187502962619
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 3.1024238213608326
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 23.776801377330436
# Calculated quote for Instrument.IRS is 0.05795385500890576
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9512245089975654)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09687955039620455
# delta_t: 0.25205479452054796
# discount_factor: 0.9512245089975654
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 2.322790864025529
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 23.976069815829046
# Calculated quote for Instrument.IRS is 0.049822717394283046
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9510521403120058)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760626916159687
# delta_t: 0.25205479452054796
# discount_factor: 0.9510521403120058
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 2.339790660232491
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 23.971725180466997
# Calculated quote for Instrument.IRS is 0.04999966041126896
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9510516403120054)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760837757662255
# delta_t: 0.25205479452054796
# discount_factor: 0.9510516403120054
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 2.3398399724450747
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 23.97171257772726
# Calculated quote for Instrument.IRS is 0.05000017370228293
# ------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------
# next instrument
# DEBUG: check if curve is growing incrementally
# [1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9510516403120054, 0.9510516403120054]
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9510516403120054, 1e-05)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03258945223761494
# delta_t: 0.2493150684931507
# discount_factor: 0.9845653836684464
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.040647113945308816
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700463521549
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760837757662255
# delta_t: 0.25205479452054796
# discount_factor: 0.9510516403120054
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 65.69494620820008
# delta_t: 0.2493150684931507
# discount_factor: 0.05458367884930559
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 64.98430015563791
# delta_t: 0.2465753424657534
# discount_factor: 0.003232662925752177
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 62.84871880018011
# delta_t: 0.24383561643835616
# discount_factor: 0.00019755906280687245
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 67.9184307476428
# delta_t: 0.25205479452054796
# discount_factor: 9.999999999999997e-06
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.748157992227346
# 0.7999634618285861
# 0.9769706912354794
# 2.3398399724450747
# 89.40118848559527
# 5.179865865265038
# 0.3027544451082427
# 0.01711916610625517
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744467351258233
# 24.54669860652839
# 24.035425800464093
# 23.97171257772726
# 1.3608533630922763
# 0.07970949679936874
# 0.004817193586249767
# 0.0002520547945205479
# Calculated quote for Instrument.IRS is 1.0103492292525516
# ----------------
# Error function trial curve
# (1.0, 0.999794553537986, 0.9993264063573297, 0.9975427192499767, 0.9951191751463713, 0.9924075995868776, 0.9845653836684464, 0.9747700463521549, 0.9510516403120054, 5.0)
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03023536460118237
# delta_t: 0.2493150684931507
# discount_factor: 0.9924978662867313
# ...
# swap calculating fwd_rate for floating leg
# forward rate: 0.0920572808511464
# delta_t: 0.2493150684931507
# discount_factor: 0.8668434525436086
# notional 9:100.0 for 2022-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09310319766648836
# delta_t: 0.2465753424657534
# discount_factor: 0.8475543367997482
# notional 10:100.0 for 2022-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205716513429033
# delta_t: 0.24383561643835616
# discount_factor: 0.8289016762791588
# notional 11:100.0 for 2022-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09308057981589446
# delta_t: 0.25205479452054796
# discount_factor: 0.8094442528321099
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# 1.989515576985035
# 1.9457264947107058
# 1.8606203084672692
# 1.899070058950021
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# 21.611713474374902
# 20.898600085473245
# 20.211575120231544
# 20.402430482343593
# Calculated quote for Instrument.IRS is 0.07000000046640098
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.024999999999992806
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.024878300077750826
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.02799999999998407
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.027947794029270022
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.028299999999994774
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.02828777500526906
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.028999999857055463
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.028993857550322116
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.030499998955627033
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.030495971788855155
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03150000015681727
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03149792046021447
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.03480000015798561
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.034798577616906176
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# Calculated quote for Instrument.IRS is 0.050000000000030125
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760342228987895
# delta_t: 0.25205479452054796
# discount_factor: 0.9510528123613405
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.3397240691422043
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.971742119792694
# Calculated quote for Instrument.IRS is 0.04999897341750754
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703769444803175
# delta_t: 0.2493150684931507
# discount_factor: 0.934608096826045
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711786296455108
# delta_t: 0.2465753424657534
# discount_factor: 0.9186247423044318
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07038099169138991
# delta_t: 0.24383561643835616
# discount_factor: 0.9030878008578432
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115715616324625
# delta_t: 0.25205479452054796
# discount_factor: 0.8867932653348046
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# Calculated quote for Instrument.IRS is 0.0599999999996925
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07037580012612477
# delta_t: 0.2493150684931507
# discount_factor: 0.9346083595837723
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711774723662175
# delta_t: 0.2465753424657534
# discount_factor: 0.9186252559947014
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703798474900744
# delta_t: 0.24383561643835616
# discount_factor: 0.9030885541759833
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115599901197278
# delta_t: 0.25205479452054796
# discount_factor: 0.8867942653348047
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398402222013244
# 1.6122433259212354
# 1.549800517657928
# 1.5904842005081528
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30119471838994
# 22.65103370945839
# 22.02051543059247
# 22.352074633096446
# Calculated quote for Instrument.IRS is 0.059999449653962464
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703769444803175
# delta_t: 0.2493150684931507
# discount_factor: 0.934608096826045
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711786296455108
# delta_t: 0.2465753424657534
# discount_factor: 0.9186247423044318
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07038099169138991
# delta_t: 0.24383561643835616
# discount_factor: 0.9030878008578432
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115715616324625
# delta_t: 0.25205479452054796
# discount_factor: 0.8867932653348046
# notional 8:100.0 for 2021-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205727931943031
# delta_t: 0.2493150684931507
# discount_factor: 0.8668434528680805
# notional 9:100.0 for 2022-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09310319611756283
# delta_t: 0.2465753424657534
# discount_factor: 0.8475543374307654
# notional 10:100.0 for 2022-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205716360295799
# delta_t: 0.24383561643835616
# discount_factor: 0.8289016771997394
# notional 11:100.0 for 2022-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09308057826696015
# delta_t: 0.25205479452054796
# discount_factor: 0.8094442540473856
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# 1.9895155446267299
# 1.9457264637889535
# 1.8606202795830407
# 1.8990700301992038
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# 21.611713482464474
# 20.89860010103257
# 20.211575142678576
# 20.4024305129752
# Calculated quote for Instrument.IRS is 0.06999999999996598
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703769444803175
# delta_t: 0.2493150684931507
# discount_factor: 0.934608096826045
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711786296455108
# delta_t: 0.2465753424657534
# discount_factor: 0.9186247423044318
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07038099169138991
# delta_t: 0.24383561643835616
# discount_factor: 0.9030878008578432
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115715616324625
# delta_t: 0.25205479452054796
# discount_factor: 0.8867932653348046
# notional 8:100.0 for 2021-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205601893522442
# delta_t: 0.2493150684931507
# discount_factor: 0.8668437198624208
# notional 9:100.0 for 2022-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09310192157214091
# delta_t: 0.2465753424657534
# discount_factor: 0.8475548566684222
# notional 10:100.0 for 2022-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205590353425407
# delta_t: 0.24383561643835616
# discount_factor: 0.8289024347071813
# notional 11:100.0 for 2022-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09307930371373274
# delta_t: 0.25205479452054796
# discount_factor: 0.8094452540473857
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# 1.989488918341841
# 1.9457010195689732
# 1.8605965119494308
# 1.8990463723240243
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# 21.6117201390357
# 20.898612904152877
# 20.21159361340798
# 20.402455718454654
# Calculated quote for Instrument.IRS is 0.06999961619005847

# %%
# plt.figure(1)
# estr_both.plot(discount_factors=True)
# plt.xlabel("year")
# plt.ylabel("DF")
# plt.legend()

# plt.figure(2)
# estr_both.plot(discount_factors=False)
# plt.xlabel("year")
# plt.ylabel("zero rate")
# plt.legend()

# %%
plt.figure(3)
dates_final = estr_both.get_dates()
df_final = estr_both.get_df()

# calculated df from dates
dates_new = [dates_final[0]]
days = 10  # create a smoother curve by adding dates in between
for i in range(1, len(dates_final)):
    while dates_new[-1] + dt.timedelta(days=days) < dates_final[i]:
        dates_new.append(dates_new[-1] + dt.timedelta(days=days))
    dates_new.append(dates_final[i])

print(dates_new)
values = [estr_both.rivapy_value(estr_both.refdate, d) for d in dates_new]
print(values)

plt.plot(dates_final, df_final, marker="^", label="bootstrapped")
plt.plot(dates_new, values, label="interpolated")

plt.xlabel("year")
plt.ylabel("DF")
plt.legend()

# continuous compounding
plt.figure(4)
dcc = DayCounter(estr_both.daycounter)
zero_final = []
for i in range(1, len(df_final)):
    delta_t = dcc.yf(estr_both.refdate, dates_final[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_final.append(-math.log(df_final[i]) / delta_t)
zero_final.insert(0, zero_final[0])  # adding first entry to account for division by zero for dt

zero_interp = []
for i in range(1, len(values)):
    delta_t = dcc.yf(estr_both.refdate, dates_new[i])  # float((dates_new[i] - estr.refdate).days) / 365.0
    zero_interp.append(-math.log(values[i]) / delta_t)
zero_interp.insert(0, zero_interp[0])

plt.plot(dates_final, zero_final, marker="^", label="bootstrapped")
# plt.scatter(end_date_deposits, quotes_deposits)
plt.plot(dates_new, zero_interp, label="interpolated")

plt.xlabel("year")
plt.ylabel("zero rates")
plt.legend()
plt.show()
# Out:
# [datetime.datetime(2019, 8, 31, 0, 0), datetime.datetime(2019, 9, 3, 0, 0), datetime.datetime(2019, 9, 9, 0, 0), datetime.datetime(2019, 9, 19, 0, 0), datetime.datetime(2019, 9, 29, 0, 0), datetime.datetime(2019, 10, 2, 0, 0), datetime.datetime(2019, 10, 12, 0, 0), datetime.datetime(2019, 10, 22, 0, 0), datetime.datetime(2019, 11, 1, 0, 0), datetime.datetime(2019, 11, 11, 0, 0), datetime.datetime(2019, 11, 21, 0, 0), datetime.datetime(2019, 12, 1, 0, 0), datetime.datetime(2019, 12, 11, 0, 0), datetime.datetime(2019, 12, 21, 0, 0), datetime.datetime(2019, 12, 31, 0, 0), datetime.datetime(2020, 1, 10, 0, 0), datetime.datetime(2020, 1, 20, 0, 0), datetime.datetime(2020, 1, 30, 0, 0), datetime.datetime(2020, 2, 9, 0, 0), datetime.datetime(2020, 2, 19, 0, 0), datetime.datetime(2020, 2, 29, 0, 0), datetime.datetime(2020, 3, 10, 0, 0), datetime.datetime(2020, 3, 20, 0, 0), datetime.datetime(2020, 3, 30, 0, 0), datetime.datetime(2020, 4, 9, 0, 0), datetime.datetime(2020, 4, 19, 0, 0), datetime.datetime(2020, 4, 29, 0, 0), datetime.datetime(2020, 5, 9, 0, 0), datetime.datetime(2020, 5, 19, 0, 0), datetime.datetime(2020, 5, 29, 0, 0), datetime.datetime(2020, 6, 8, 0, 0), datetime.datetime(2020, 6, 18, 0, 0), datetime.datetime(2020, 6, 28, 0, 0), datetime.datetime(2020, 7, 8, 0, 0), datetime.datetime(2020, 7, 18, 0, 0), datetime.datetime(2020, 7, 28, 0, 0), datetime.datetime(2020, 8, 7, 0, 0), datetime.datetime(2020, 8, 17, 0, 0), datetime.datetime(2020, 8, 27, 0, 0), datetime.datetime(2020, 8, 31, 0, 0), datetime.datetime(2020, 9, 10, 0, 0), datetime.datetime(2020, 9, 20, 0, 0), datetime.datetime(2020, 9, 30, 0, 0), datetime.datetime(2020, 10, 10, 0, 0), datetime.datetime(2020, 10, 20, 0, 0), datetime.datetime(2020, 10, 30, 0, 0), datetime.datetime(2020, 11, 9, 0, 0), datetime.datetime(2020, 11, 19, 0, 0), datetime.datetime(2020, 11, 29, 0, 0), datetime.datetime(2020, 12, 9, 0, 0), datetime.datetime(2020, 12, 19, 0, 0), datetime.datetime(2020, 12, 29, 0, 0), datetime.datetime(2021, 1, 8, 0, 0), datetime.datetime(2021, 1, 18, 0, 0), datetime.datetime(2021, 1, 28, 0, 0), datetime.datetime(2021, 2, 7, 0, 0), datetime.datetime(2021, 2, 17, 0, 0), datetime.datetime(2021, 2, 27, 0, 0), datetime.datetime(2021, 3, 9, 0, 0), datetime.datetime(2021, 3, 19, 0, 0), datetime.datetime(2021, 3, 29, 0, 0), datetime.datetime(2021, 4, 8, 0, 0), datetime.datetime(2021, 4, 18, 0, 0), datetime.datetime(2021, 4, 28, 0, 0), datetime.datetime(2021, 5, 8, 0, 0), datetime.datetime(2021, 5, 18, 0, 0), datetime.datetime(2021, 5, 28, 0, 0), datetime.datetime(2021, 6, 7, 0, 0), datetime.datetime(2021, 6, 17, 0, 0), datetime.datetime(2021, 6, 27, 0, 0), datetime.datetime(2021, 7, 7, 0, 0), datetime.datetime(2021, 7, 17, 0, 0), datetime.datetime(2021, 7, 27, 0, 0), datetime.datetime(2021, 8, 6, 0, 0), datetime.datetime(2021, 8, 16, 0, 0), datetime.datetime(2021, 8, 26, 0, 0), datetime.datetime(2021, 8, 31, 0, 0), datetime.datetime(2021, 9, 10, 0, 0), datetime.datetime(2021, 9, 20, 0, 0), datetime.datetime(2021, 9, 30, 0, 0), datetime.datetime(2021, 10, 10, 0, 0), datetime.datetime(2021, 10, 20, 0, 0), datetime.datetime(2021, 10, 30, 0, 0), datetime.datetime(2021, 11, 9, 0, 0), datetime.datetime(2021, 11, 19, 0, 0), datetime.datetime(2021, 11, 29, 0, 0), datetime.datetime(2021, 12, 9, 0, 0), datetime.datetime(2021, 12, 19, 0, 0), datetime.datetime(2021, 12, 29, 0, 0), datetime.datetime(2022, 1, 8, 0, 0), datetime.datetime(2022, 1, 18, 0, 0), datetime.datetime(2022, 1, 28, 0, 0), datetime.datetime(2022, 2, 7, 0, 0), datetime.datetime(2022, 2, 17, 0, 0), datetime.datetime(2022, 2, 27, 0, 0), datetime.datetime(2022, 3, 9, 0, 0), datetime.datetime(2022, 3, 19, 0, 0), datetime.datetime(2022, 3, 29, 0, 0), datetime.datetime(2022, 4, 8, 0, 0), datetime.datetime(2022, 4, 18, 0, 0), datetime.datetime(2022, 4, 28, 0, 0), datetime.datetime(2022, 5, 8, 0, 0), datetime.datetime(2022, 5, 18, 0, 0), datetime.datetime(2022, 5, 28, 0, 0), datetime.datetime(2022, 6, 7, 0, 0), datetime.d ...
# [1.0, 0.9997945486926025, 0.9993264031821744, 0.998550495497777, 0.9977751902519151, 0.9975427160837325, 0.9967342129505598, 0.9959263651049308, 0.9951191720157387, 0.9942135522191957, 0.9933087565925, 0.9924047843856059, 0.9915306696144695, 0.9906573247677077, 0.9897847491671677, 0.9889129421352939, 0.9880419029951274, 0.9871716310703054, 0.9863021256850611, 0.985433386164223, 0.9845654118332141, 0.9834721946628219, 0.982380191351628, 0.981289400551818, 0.9801998209170737, 0.9791114511025717, 0.9780242897649821, 0.9769383355624666, 0.9758535871546764, 0.9747700432027515, 0.972218966374835, 0.9696745659861742, 0.9671368245638181, 0.9646057246805441, 0.962081248954738, 0.9595633800502757, 0.9570521006764036, 0.9545473935876193, 0.9520492415835542, 0.9510518123613405, 0.9492307523618209, 0.9474131793011606, 0.9455990865026207, 0.9437884673022464, 0.9419813150488432, 0.9401776231039519, 0.9383773848418251, 0.9365805936494015, 0.9347872429262831, 0.9329973260847099, 0.9312108365495361, 0.9294277677582058, 0.9276481131607293, 0.9258718662196582, 0.9240990204100625, 0.9223295692195057, 0.9205635061480212, 0.9188008247080884, 0.9170415184246093, 0.9152855808348839, 0.913533005488587, 0.9117837859477443, 0.9100379157867092, 0.9082953885921385, 0.9065561979629693, 0.9048203375103953, 0.9030878008578432, 0.90135858164095, 0.8996326735075386, 0.8979100701175952, 0.8961907651432456, 0.8944747522687323, 0.892762025190391, 0.8910525776166277, 0.8893464032678952, 0.8876434958766704, 0.8867932653348046, 0.8845787123522424, 0.8823696896833444, 0.8801661835174817, 0.8779681800785143, 0.8757756656247047, 0.873588626448632, 0.8714070488771065, 0.8692309192710839, 0.86706022402558, 0.8648949495695861, 0.8627350823659835, 0.8605806089114593, 0.858431515736422, 0.856287789404917, 0.8541494165145429, 0.8520163836963676, 0.8498886776148443, 0.8477662849677292, 0.8456491924859971, 0.8435373869337592, 0.8414308551081802, 0.8393295838393956, 0.8372335599904296, 0.8351427704571126, 0.8330572021679997, 0.830976842084289, 0.8289016771997394, 0.8268316945405899, 0.8247668811654787, 0.8227072241653617, 0.8206527106634317, 0.8186033278150389, 0.8165590628076093, 0.8145199028605656, 0.8124858352252469, 0.8104568471848287, 0.8094442540473856]

# %%
model_quotes = []
pricing_params = {"fixing_grace_period": 0.0, "set_rate": True, "desired_rate": 1.0}
curves_dict = {"discount_curve": estr_both, "fixing_curve":estr_both}




for i in range(len(instruments_both)):

    model_quote = get_quote(ref_date, instruments_both[i], curves_dict )

    print(model_quote)
    model_quotes.append(model_quote)
# Out:
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-03 00:00:00
# 0.0027397260273972603
# Calculated quote for Instrument.Deposit is 0.024999999999992806
# 0.024999999999992806
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-09-09 00:00:00
# 0.019178082191780823
# Calculated quote for Instrument.Deposit is 0.02799999999998407
# 0.02799999999998407
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-10-02 00:00:00
# 0.0821917808219178
# Calculated quote for Instrument.Deposit is 0.028299999999994774
# 0.028299999999994774
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-11-01 00:00:00
# 0.1643835616438356
# Calculated quote for Instrument.Deposit is 0.028999999857055463
# 0.028999999857055463
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2019-12-02 00:00:00
# 0.2493150684931507
# Calculated quote for Instrument.Deposit is 0.030499998955627033
# 0.030499998955627033
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-02-28 00:00:00
# 0.4904109589041096
# Calculated quote for Instrument.Deposit is 0.03150000015681727
# 0.03150000015681727
# Depopsit Pricing, start, mat, yf
# 2019-09-02 00:00:00
# 2020-05-29 00:00:00
# 0.7397260273972602
# Calculated quote for Instrument.Deposit is 0.03480000015798561
# 0.03480000015798561
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# Calculated quote for Instrument.IRS is 0.050000000000030125
# 0.050000000000030125
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703769444803175
# delta_t: 0.2493150684931507
# discount_factor: 0.934608096826045
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711786296455108
# delta_t: 0.2465753424657534
# discount_factor: 0.9186247423044318
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07038099169138991
# delta_t: 0.24383561643835616
# discount_factor: 0.9030878008578432
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115715616324625
# delta_t: 0.25205479452054796
# discount_factor: 0.8867932653348046
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# Calculated quote for Instrument.IRS is 0.0599999999996925
# 0.0599999999996925
# generating cashflow table for FLOAT leg
# notional 0:100.0 for 2019-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.030246416689349687
# delta_t: 0.2493150684931507
# discount_factor: 0.9924951445737664
# notional 1:100.0 for 2020-02-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.03257815383257104
# delta_t: 0.2493150684931507
# discount_factor: 0.9845654118332141
# notional 2:100.0 for 2020-05-29 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.04064724401914276
# delta_t: 0.2465753424657534
# discount_factor: 0.9747700432027515
# notional 3:100.0 for 2020-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09760763911621062
# delta_t: 0.25205479452054796
# discount_factor: 0.9510518123613405
# notional 4:100.0 for 2020-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0703769444803175
# delta_t: 0.2493150684931507
# discount_factor: 0.934608096826045
# notional 5:100.0 for 2021-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.0711786296455108
# delta_t: 0.2465753424657534
# discount_factor: 0.9186247423044318
# notional 6:100.0 for 2021-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07038099169138991
# delta_t: 0.24383561643835616
# discount_factor: 0.9030878008578432
# notional 7:100.0 for 2021-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.07115715616324625
# delta_t: 0.25205479452054796
# discount_factor: 0.8867932653348046
# notional 8:100.0 for 2021-11-30 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205727931943031
# delta_t: 0.2493150684931507
# discount_factor: 0.8668434528680805
# notional 9:100.0 for 2022-02-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09310319611756283
# delta_t: 0.2465753424657534
# discount_factor: 0.8475543374307654
# notional 10:100.0 for 2022-05-28 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09205716360295799
# delta_t: 0.24383561643835616
# discount_factor: 0.8289016771997394
# notional 11:100.0 for 2022-08-31 00:00:00
# swap calculating fwd_rate for floating leg
# forward rate: 0.09308057826696015
# delta_t: 0.25205479452054796
# discount_factor: 0.8094442540473856
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 0.7484294178490519
# 0.7996861461612961
# 0.97697381445894
# 2.339822693568249
# 1.6398664259856277
# 1.612268637921122
# 1.5498244207618244
# 1.5905082716895416
# 1.9895155446267299
# 1.9457264637889535
# 1.8606202795830407
# 1.8990700301992038
# generating cashflow table for FIXED leg
# ----------------------------------------------------------
# DEBUG: price leg pv values
# 24.744399494852807
# 24.54669930871849
# 24.03542572280757
# 23.97171691431324
# 23.30118816744386
# 22.651021043122974
# 22.020497062013163
# 22.352049427616993
# 21.611713482464474
# 20.89860010103257
# 20.211575142678576
# 20.4024305129752
# Calculated quote for Instrument.IRS is 0.06999999999996598
# 0.06999999999996598

# %%
for i in range(len(quotes_both)):

    per_diff = (model_quotes[i] - quotes_both[i])/quotes_both[i] * 100
    print(f"{model_quotes[i]} - {quotes_both[i]})")
    print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")
# Out:
# 0.024999999999992806 - 0.025)
# i:0 date:2019-09-03 00:00:00  percent diff: -2.8782531913407183e-11
# 0.02799999999998407 - 0.028)
# i:1 date:2019-09-09 00:00:00  percent diff: -5.689893001203927e-11
# 0.028299999999994774 - 0.0283)
# i:2 date:2019-10-02 00:00:00  percent diff: -1.8462851977534074e-11
# 0.028999999857055463 - 0.029)
# i:3 date:2019-11-01 00:00:00  percent diff: -4.929122005195479e-07
# 0.030499998955627033 - 0.0305)
# i:4 date:2019-12-01 00:00:00  percent diff: -3.424173660917663e-06
# 0.03150000015681727 - 0.0315)
# i:5 date:2020-02-29 00:00:00  percent diff: 4.978325952534202e-07
# 0.03480000015798561 - 0.0348)
# i:6 date:2020-05-29 00:00:00  percent diff: 4.53981639956298e-07
# 0.050000000000030125 - 0.05)
# i:7 date:2020-08-31 00:00:00  percent diff: 6.024347687372256e-11
# 0.0599999999996925 - 0.06)
# i:8 date:2021-08-31 00:00:00  percent diff: -5.124951389194148e-10
# 0.06999999999996598 - 0.07)
# i:9 date:2022-08-31 00:00:00  percent diff: -4.861190814965864e-11

# %%
quotes_both

# %%
model_quotes

# %%
# for i in range(len(quotes_both)):

#     per_diff = (model_quotes[i] - quotes_both[i])/quotes_both[i] * 100
#     print(f"i:{i} date:{dates_final[i+1]}  percent diff: {per_diff}")

# %%
b_curve_df = estr_both.get_df()

# %%
estr_both.get_df()

# %%
df1 = b_curve_df[5]#3m
df2=b_curve_df[6]#6m
df3=b_curve_df[7]#9m
df0=1

print(df1)
C = 0.05


df4 = (1-C*0.25*(df1+df2+df3)) /(1+0.25*C)
#df4 = (df0+df1+df2+df3)/C - (df1+df2+df3)
print(f"DF4 : {df4}")

# %%
b_curve_dates =estr_both.get_dates()
print(b_curve_dates)

# %%
estr_both.get_dates()

# %%
print(len(b_curve_dates))
print(len(b_curve_df))

# %% [markdown]
# ## Sanity check
#
# here we took the discount factors for the 3m,6m, 9m deposits and from this, calculated the DISCOUTN FACTOR OF 1 Year for a 1 year swap based on these other discount factors and that the swap fair rate necessicates that float_pv = fixed_pv

# %%
manual_df = [1.0,
 0.9997945486926025,
 0.9993264031821744,
 0.9975427160837325,
 0.9951191720157387,
 0.9924047843856059,
 0.9845654118332141,
 0.9747700432027515,
0.9558756419558913# 0.951213083463931000
             ]

# manual_dates =[ref_date, 
#                ref_date + dt.timedelta(days=120), 
#                ref_date + dt.timedelta(days=180), 
#                ref_date + dt.timedelta(days=270), 
#                ref_date + dt.timedelta(days=360)]
# manual_dates =[b_curve_dates[0],
#                b_curve_dates[5],
#                b_curve_dates[6],
#                b_curve_dates[7],
#                b_curve_dates[8],
#                ]

# manual_quotes = [0.0305,0.0315,0.0348, 0.05]


manual_curve = dc = DiscountCurve(id="manual_dc", 
                                  refdate=ref_date, dates=b_curve_dates, df=manual_df, 
                                  interpolation=InterpolationType.LINEAR_LOG, extrapolation=ExtrapolationType.LINEAR_LOG)

# %%
# instruments_man = [other_deposits[5],
#                    other_deposits[6],
#                    other_deposits[7],
#                    other_swaps[0]


# for i in instruments_man:
#     print_member_values(i)

for i in range(len(other_deposits)):
    print(f"{i} : {other_deposits[i].maturity_date}")

# %%
pricing_params = {"fixing_grace_period": 0.0, "set_rate": True, "desired_rate": 1.0}
curves_dict = {"discount_curve": manual_curve, "fixing_curve":manual_curve}
model_quotes=[]



for i in range(len(instruments_both)):

    model_quote = get_quote(ref_date, instruments_both[i], curves_dict )

    print()
    print(f"MODEL QUOTE: {model_quote}")
    print()
    model_quotes.append(model_quote)


# simply_rate = []
# for i in range(len(other_deposits)):
#     val =DepositPricer.implied_simply_compounded_rate(ref_date, other_deposits[i], estr)
#     simply_rate.append(val)

# %%
0.19802011890454535/4

# %%
for i in range(len(quotes_both)):

    per_diff = (model_quotes[i] - quotes_both[i])/quotes_both[i] * 100
    print(f"{model_quotes[i]} - {quotes_both[i]})")
    print(f"i:{i} date:{b_curve_dates[i+1]}  percent diff: {per_diff}")
